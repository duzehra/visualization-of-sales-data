# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlgiib.pyplot as plt
import datetime

# %%
df = pd.read_excel("C:/Users/Zehra/Desktop/powerbi/satış_verileri.xlsx")

# %%
df.head()
# Out:
#        Tarih    Satış  Personel
# 0 2010-01-01  37178.0       160
# 1 2010-02-01  43042.3       164
# 2 2010-03-01  49223.8       155
# 3 2010-04-01  36105.5       163
# 4 2010-05-01  41360.5       155

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tarih     94 non-null     datetime64[ns]
#  1   Satış     94 non-null     float64
#  2   Personel  94 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 2.3 KB

# %%
plt.plot(df.Tarih, df.Satış)
plt.xlabel("Tarih")
plt.ylabel("Satış Sayısı")
plt.show()

# %%
f=plt.figure(figsize=(12,4))
axes1=f.add_axes([0.1,0.1,0.9,0.9])
axes2=f.add_axes([0.6,0.3,0.3,0.3])
axes1.plot(df.Tarih, df.Satış)
axes2.plot(df.Tarih, df.Personel, color="red")
axes1.set_xlabel("Tarih")
axes2.set_xlabel("Tarih")
axes1.set_ylabel("Satış")
axes2.set_ylabel("Personel Sayısı")
plt.show()
